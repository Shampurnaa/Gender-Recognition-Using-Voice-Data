# 3     0.250000  0.201497  0.007812  0.562500  0.554688  0.247119      1
# 4     0.266667  0.712812  0.007812  5.484375  5.476562  0.208274      1
# ...        ...       ...       ...       ...       ...       ...    ...
# 3163  0.262295  0.832899  0.007812  4.210938  4.203125  0.161929      0
# 3164  0.275862  0.909856  0.039062  3.679688  3.640625  0.277897      0
# 3165  0.275862  0.494271  0.007812  2.937500  2.929688  0.194759      0
# 3166  0.250000  0.791360  0.007812  3.593750  3.585938  0.311002      0
# 3167  0.271186  0.227022  0.007812  0.554688  0.546875  0.350000      0
#
# [3168 rows x 21 columns]

# %%
y = data['label'].copy()
X = data.drop('label', axis=1).copy()

# %%
scaler = StandardScaler()

X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %%
X.shape
# Out:
# (3168, 20)

# %%
inputs = tf.keras.Input(shape=(X.shape[1],))

x = tf.keras.layers.Dense(64, activation='relu')(inputs)
x = tf.keras.layers.Dense(64, activation='relu')(x)

outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 20)]              0
#
#  dense (Dense)               (None, 64)                1344
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 5569 (21.75 KB)
# Trainable params: 5569 (21.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        tf.keras.metrics.AUC(name='auc')
    ]
)

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=32,
    epochs=100,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/100
# 56/56 [==============================] - 4s 19ms/step - loss: 0.4035 - accuracy: 0.8646 - auc: 0.9369 - val_loss: 0.1896 - val_accuracy: 0.9730 - val_auc: 0.9960
# Epoch 2/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1542 - accuracy: 0.9583 - auc: 0.9906 - val_loss: 0.0919 - val_accuracy: 0.9662 - val_auc: 0.9977
# Epoch 3/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0959 - accuracy: 0.9701 - auc: 0.9945 - val_loss: 0.0643 - val_accuracy: 0.9797 - val_auc: 0.9980
# Epoch 4/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0751 - accuracy: 0.9741 - auc: 0.9963 - val_loss: 0.0560 - val_accuracy: 0.9865 - val_auc: 0.9979
# Epoch 5/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0660 - accuracy: 0.9797 - auc: 0.9971 - val_loss: 0.0617 - val_accuracy: 0.9865 - val_auc: 0.9969
# Epoch 6/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0659 - accuracy: 0.9769 - auc: 0.9970 - val_loss: 0.0470 - val_accuracy: 0.9910 - val_auc: 0.9984
# Epoch 7/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0586 - accuracy: 0.9786 - auc: 0.9971 - val_loss: 0.0529 - val_accuracy: 0.9865 - val_auc: 0.9978
# Epoch 8/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0537 - accuracy: 0.9808 - auc: 0.9980 - val_loss: 0.0445 - val_accuracy: 0.9887 - val_auc: 0.9986
# Epoch 9/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0510 - accuracy: 0.9814 - auc: 0.9980 - val_loss: 0.0440 - val_accuracy: 0.9887 - val_auc: 0.9985
# Epoch 10/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0473 - accuracy: 0.9870 - auc: 0.9984 - val_loss: 0.0504 - val_accuracy: 0.9842 - val_auc: 0.9976
# Epoch 11/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0435 - accuracy: 0.9853 - auc: 0.9985 - val_loss: 0.0428 - val_accuracy: 0.9865 - val_auc: 0.9987
# Epoch 12/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0458 - accuracy: 0.9859 - auc: 0.9985 - val_loss: 0.0487 - val_accuracy: 0.9842 - val_auc: 0.9975
# Epoch 13/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0412 - accuracy: 0.9859 - auc: 0.9987 - val_loss: 0.0430 - val_accuracy: 0.9865 - val_auc: 0.9986
# Epoch 14/100
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0404 - accuracy: 0.9876 - auc: 0.9988 - val_loss: 0.0438 - val_accuracy: 0.9865 - val_auc: 0.9984

# %%
model.evaluate(X_test, y_test)
# Out:
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0694 - accuracy: 0.9842 - auc: 0.9961
# [0.06942644715309143, 0.9842271208763123, 0.9960828423500061]

# %% [markdown]
# **USING 2D CNNs**

# %%
X = tf.keras.preprocessing.sequence.pad_sequences(X, dtype=np.float, maxlen=25, padding='post')
X = X.reshape(-1, 5, 5)
X = np.expand_dims(X, axis=3)
# Out:
# <ipython-input-18-1cd93647b5ab>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X = tf.keras.preprocessing.sequence.pad_sequences(X, dtype=np.float, maxlen=25, padding='post')

# %%
X.shape
# Out:
# (3168, 5, 5, 1)

# %%
plt.figure(figsize=(12, 12))

for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(np.squeeze(X[i]))
    plt.axis('off')

plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %%
inputs = tf.keras.Input(shape=(X.shape[1], X.shape[2], X.shape[3]))

x = tf.keras.layers.Conv2D(16, 2, activation='relu')(inputs)
x = tf.keras.layers.MaxPooling2D()(x)

x = tf.keras.layers.Conv2D(32, 1, activation='relu')(x)
x = tf.keras.layers.MaxPooling2D()(x)

x = tf.keras.layers.Flatten()(x)

x = tf.keras.layers.Dense(64, activation='relu')(x)

outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5, 5, 1)]         0
#
#  conv2d (Conv2D)             (None, 4, 4, 16)          80
#
#  max_pooling2d (MaxPooling2  (None, 2, 2, 16)          0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 2, 2, 32)          544
#
#  max_pooling2d_1 (MaxPoolin  (None, 1, 1, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense_3 (Dense)             (None, 64)                2112
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2801 (10.94 KB)
# Trainable params: 2801 (10.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        tf.keras.metrics.AUC(name='auc')
    ]
)

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=32,
    epochs=100,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/100
# 56/56 [==============================] - 2s 9ms/step - loss: 0.6558 - accuracy: 0.6390 - auc: 0.7215 - val_loss: 0.6111 - val_accuracy: 0.7027 - val_auc: 0.8030
# Epoch 2/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.5376 - accuracy: 0.7891 - auc: 0.8723 - val_loss: 0.4726 - val_accuracy: 0.7905 - val_auc: 0.8925
# Epoch 3/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3993 - accuracy: 0.8613 - auc: 0.9327 - val_loss: 0.3511 - val_accuracy: 0.8739 - val_auc: 0.9454
# Epoch 4/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2984 - accuracy: 0.9041 - auc: 0.9593 - val_loss: 0.2695 - val_accuracy: 0.8986 - val_auc: 0.9643
# Epoch 5/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.2418 - accuracy: 0.9137 - auc: 0.9704 - val_loss: 0.2299 - val_accuracy: 0.9122 - val_auc: 0.9727
# Epoch 6/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2061 - accuracy: 0.9216 - auc: 0.9765 - val_loss: 0.2005 - val_accuracy: 0.9189 - val_auc: 0.9785
# Epoch 7/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1942 - accuracy: 0.9244 - auc: 0.9786 - val_loss: 0.1869 - val_accuracy: 0.9369 - val_auc: 0.9810
# Epoch 8/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1757 - accuracy: 0.9334 - auc: 0.9821 - val_loss: 0.1772 - val_accuracy: 0.9347 - val_auc: 0.9822
# Epoch 9/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1705 - accuracy: 0.9323 - auc: 0.9829 - val_loss: 0.1653 - val_accuracy: 0.9369 - val_auc: 0.9843
# Epoch 10/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1589 - accuracy: 0.9385 - auc: 0.9851 - val_loss: 0.1592 - val_accuracy: 0.9392 - val_auc: 0.9864
# Epoch 11/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1539 - accuracy: 0.9397 - auc: 0.9855 - val_loss: 0.1623 - val_accuracy: 0.9392 - val_auc: 0.9848
# Epoch 12/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1482 - accuracy: 0.9453 - auc: 0.9866 - val_loss: 0.1529 - val_accuracy: 0.9482 - val_auc: 0.9860
# Epoch 13/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.1403 - accuracy: 0.9464 - auc: 0.9881 - val_loss: 0.1562 - val_accuracy: 0.9414 - val_auc: 0.9883
# Epoch 14/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.1376 - accuracy: 0.9515 - auc: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9505 - val_auc: 0.9870
# Epoch 15/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.1281 - accuracy: 0.9521 - auc: 0.9898 - val_loss: 0.1402 - val_accuracy: 0.9550 - val_auc: 0.9883
# Epoch 16/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.1249 - accuracy: 0.9509 - auc: 0.9904 - val_loss: 0.1337 - val_accuracy: 0.9505 - val_auc: 0.9891
# Epoch 17/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.1182 - accuracy: 0.9588 - auc: 0.9916 - val_loss: 0.1303 - val_accuracy: 0.9550 - val_auc: 0.9893
# Epoch 18/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.1148 - accuracy: 0.9577 - auc: 0.9918 - val_loss: 0.1364 - val_accuracy: 0.9527 - val_auc: 0.9889
# Epoch 19/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.1157 - accuracy: 0.9532 - auc: 0.9917 - val_loss: 0.1245 - val_accuracy: 0.9527 - val_auc: 0.9902
# Epoch 20/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.1057 - accuracy: 0.9628 - auc: 0.9930 - val_loss: 0.1525 - val_accuracy: 0.9459 - val_auc: 0.9886
# Epoch 21/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.1168 - accuracy: 0.9560 - auc: 0.9916 - val_loss: 0.1286 - val_accuracy: 0.9505 - val_auc: 0.9914
# Epoch 22/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.1087 - accuracy: 0.9588 - auc: 0.9922 - val_loss: 0.1256 - val_accuracy: 0.9505 - val_auc: 0.9918

# %%
model.evaluate(X_test, y_test)
# Out:
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1140 - accuracy: 0.9474 - auc: 0.9929
# [0.11398093402385712, 0.9474237561225891, 0.9929149150848389]
